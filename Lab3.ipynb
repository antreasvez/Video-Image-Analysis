# %% [markdown]
# #3η ομαδική άσκηση στη Τεχνολογία και Ανάλυση Εικόνων και Βίντεο

# %% [markdown]
# * Ανδρέας Βεζάκης ΑΜ: 03117186
# * Σταύρος Κινικλής ΑΜ: 03117608
#
#
# ## Θεωρητικό Μέρος
#
# 1. <b>Γιατί και πώς τα συνελικτικά δίκτυα άλλαξαν το τοπίο της παραδοσιακής επεξεργασίας
# εικόνας;</b>
#
# Πριν τα συνελικτικά νευρωνικά δίκτυα (convolutional neural networks, CNN) η επεξεργασία των εικόνων ήταν πολύ πιο χρονοβόρα και υπολογιστικά ακριβή, αφού χρησιμοποιούνται βάρη για κάθε πίξελ της εικόνας. Για παράδειγμα μία εικόνα υψηλής ανάλυσης(512 x 762 RGB) η επεξεργασία της είναι πολύ χρονοβόρα και υπολογιστικά ακριβή. Ωστόσο, τα τελευταία χρόνια βρέθηκε ότι υπάρχει δυνατότητα "απλοποίησης" της εικόνας, ανιχνεύοντας  χαρακτηριστικά και υφές της, δηλαδή σημεία ενδιαφέροντος, και εφαρμόζοντας τα βάρη μόνο στις συγκεκριμένες περιοχές. Επομένως, τα CNN με αυτό το τρόπο μπορούν σε ογκώδη δεδομένα να εξάγουν χαρακτηριστικά για τις εικόνες και να τις κατηγοριοποιήσουν. Αρχικά, τα δίκτυα μας, χρησιμοποιούν συνέλιξη για να "μαθαίνουν" μόνα τους τα βάρη των φίλτρων, έπειτα μέσω ενός pooling layer  μειώνουν τη διάσταση της εισόδου, στη συνέχεια επιλέγεται η συνάρτηση ενεργοποίησης (ReLu) και τέλος ο τελευταίος τανυστής εξόδου τροφοδοτείται από τη συνελικτική βάση σε ένα ή πολλά dense networks.
#
# 2. <b> Περιγράψτε τη λειτουργία της Rectified Linear Unit (ReLU).</b>
#
# Η Rectified Linear Unit (ReLU) είναι μία γραμμική συνάρτηση, η οποία εκφράζεται από τον τύπο: <br>
# <center>  <b> <i> f(x)=max⁡(0,x) </i> </b> </center>
# Χρησιμοποιείται στα νευρωνικά δίκτυα λόγω της απλότητάς της και της συμβολής της στην υψηλή απόδοση τους (επιτυγχάνει γραμμική αύξηση του υπολογιστικού κόστους του CNN μας). Η είσοδός της συγκρίνεται με το μηδέν και σε περίπτωση που δεν είναι θετική η τιμή της εισόδου, τότε στην έξοδό της έχει το μηδέν, διαφορετικά, η συνάρτηση παίρνει την τιμή της εισόδου.
#
# 3. <b> Παρουσιάστε ένα συγκριτικό πίνακα με τα επίπεδα, το μέγεθος των φίλτρων, συνάρτηση
# ενεργοποίησης, πλήθος παραμέτρων και τεχνικές pooling και dropout που χρησιμοποιούν
# τα 3 διαφορετικά δίκτυα που παρουσιάζονται στα προαναφερθέντα άρθρα και σχολιάστε
# επαρκώς τις διαφορές τους. Ποια χαρακτηριστικά αυτών των τριών δικτύων είναι κατά τη
# γνώμη σας αυτά που συνέβαλαν στη σταδιακή αύξηση της ακρίβειας ταξινόμησης.
# </b>
#
# Για τη διαμόρφωση του παρακάτω πίνακα βασιστήκαμε στα μοντέλα που υλοποιήσαμε στα επόμενα ερωτήματα.

# %% [markdown]
# Συγκριτικός Πίνακας| LeNet              | AlexNet          | VGG
# -------------------|------------------  |------------------|------------------
# Επίπεδα            |7 (8 με είσοδο)    | 11 (12 με είσοδο)| 8 convolutional layers και 3 fully-connected layers
# Μέγεθος Φίλτρων    |convolution: 5x5, average pooling:2×2 |convolution: 11x11,5x5,3x3, maximum pooling: 3x3| convolution: 3x3, maximum pooling: 2x2
# Συνάρτηση Ενεργοποίησης| sigmoid                   |   ReLu | ReLu
# Συνολικές Παράμετροι|     94,312          |21,990,884       |28,512,740
# Εκπαιδευόμενες Παράμετροι|  94,312             |21,990,884  |28,512,740
# Μη εκπαιδευόμενες Παράμετροι| 0           |2,752            |0
# Τεχνικές Pooling    | average pooling              |maximum pooling                   |maximum pooling
# Dropout             |       2x2 average pooling με stride 2            | 3x3 maximum pooling με stride 2, dropout rate                   |Dropout(0.5)

# %% [markdown]
# Αρχικά, παρατηρούμε ότι τα μοντέλα AlexNet και VGG χρησιμοιποιούν για υποδειγματοληψία την τεχνική maximum pooling και την τεχνική Dropout, και για συνάρτηση εναργοποίησης την ReLU, ενώ το LeNet χρησιμοποιεί average pooling και sigmoid συνάρτηση ενεργοποίησης. Ακόμη, ο αριθμός των fully-connected επιπέδων παραμένει σταθερός σε όλα τα CNN.
#
# Ο παράγοντας που συνέβαλε περισσότερο στη σταδιακή αύξηση της ακρίβειας ταξινόμησης είναι η συνάρτηση ενεργοποίησης ReLU. Καθώς, όπως είπαμε και στο παραπάνω ερώτημα, επιτυγχάνει γραμμική αύξηση του υπολογιστικού κόστους και όχι εκθετική (συγκρίνει την είσοδο με το 0). Επίσης, το μοντέλο θα εκπαιδεύεται ταχύτερα αφού η παράγωγος θα είναι σταθερή και συγκεκριμένα ίση με 1. Τέλος, σε σύκριση με την sigmoid συνάρτηση, αναπαρηστά την είσοδο με πιο ωφέλιμη μορφή, αφού "κόβει" τις αρνητικές τιμές, ενώ η σιγμοειδής εμφανίζει μη μηδενικά αποτελέσματα και συνεπώς υπάρχει πιο πυκνή αναπαράσταση της εισόδου.

# %% [markdown]
# ## Εισαγωγή και επισκόπηση του συνόλου δεδομένων

# %%
from __future__ import absolute_import, division, print_function, unicode_literals # legacy compatibility

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# helper functions

# select from from_list elements with index in index_list
def select_from_list(from_list, index_list):
  filtered_list= [from_list[i] for i in index_list]
  return(filtered_list)

# append in filtered_list the index of each element of unfilterd_list if it exists in in target_list
def get_ds_index(unfiliterd_list, target_list):
  index = 0
  filtered_list=[]
  for i_ in unfiliterd_list:
    if i_[0] in target_list:
      filtered_list.append(index)
    index += 1
  return(filtered_list)

# %%
# load the entire dataset
import tensorflow as tf
from tensorflow.keras import datasets, layers, models

(x_train_all, y_train_all), (x_test_all, y_test_all) = tf.keras.datasets.cifar100.load_data(label_mode='fine')
# Out:
# ...
# 169009152/169001437 [==============================] - 2s 0us/step

# %%
print(x_train_all.shape)
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# Η κάθε ομάδα θα δουλέψει με διαφορετικό υποσύνολο του dataset.
# Στο επόμενο κελί, αντικαταστήστε την τιμή της μεταβλητής `team_seed` με τον αριθμό που αντιστοιχεί στην ομάδας σας.

# %%
# REPLACE WITH YOUR TEAM NUMBER
team_seed = 25

# %%
# select from CIFAR100 20 classes
cifar100_classes_url = "https://pastebin.com/raw/nzE1n98V"

# %% [markdown]
# Δημιουργούμε το μοναδικό dataset της ομάδας μας:

# %%
team_classes = pd.read_csv(cifar100_classes_url, sep=',', header=None)
CIFAR100_LABELS_LIST = pd.read_csv('https://pastebin.com/raw/qgDaNggt', sep=',', header=None).astype(str).values.tolist()[0]

our_index = team_classes.iloc[team_seed,:].values.tolist()
our_classes = select_from_list(CIFAR100_LABELS_LIST, our_index)
train_index = get_ds_index(y_train_all, our_index)
test_index = get_ds_index(y_test_all, our_index)

x_train_ds = np.asarray(select_from_list(x_train_all, train_index))
y_train_ds = np.asarray(select_from_list(y_train_all, train_index))
x_test_ds = np.asarray(select_from_list(x_test_all, test_index))
y_test_ds = np.asarray(select_from_list(y_test_all, test_index))

# %%
# print our classes
print(our_classes)
# Out:
# [' aquarium_fish', ' baby', ' bee', ' bicycle', ' bottle', ' camel', ' cup', ' elephant', ' lamp', ' lion', ' man', ' maple_tree', ' orange', ' pear', ' rabbit', ' rose', ' sunflower', ' telephone', ' train', ' wolf']

# %%
print(x_train_ds[1].shape)
# Out:
# (32, 32, 3)

# %%
# get (train) dataset dimensions
data_size, img_rows, img_cols, img_channels = x_train_ds.shape

# set validation set percentage (wrt the training set size)
validation_percentage = 0.15
val_size = round(validation_percentage * data_size)

# Reserve val_size samples for validation and normalize all values
x_val = x_train_ds[-val_size:]/255
y_val = y_train_ds[-val_size:]
x_train = x_train_ds[:-val_size]/255
y_train = y_train_ds[:-val_size]
x_test = x_test_ds/255
y_test = y_test_ds

# summarize loaded dataset
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

# get class label from class index
def class_label_from_index(fine_category):
  return(CIFAR100_LABELS_LIST[fine_category.item(0)])

# plot first few images
plt.figure(figsize=(6, 6))
for i in range(9):
	# define subplot
  plt.subplot(330 + 1 + i).set_title(class_label_from_index(y_train[i]))
	# plot raw pixel data
  plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
  #show the figure
plt.show()
# Out:
# Train: X=(8500, 32, 32, 3), y=(8500, 1)
# Validation: X=(1500, 32, 32, 3), y=(1500, 1)
# Test: X=(2000, 32, 32, 3), y=(2000, 1)

# %% [markdown]
# # Ερώτημα 1

# %% [markdown]
# ## Αξιολόγηση των αποτελεσμάτων:
# * Για όλα τα μοντέλα, αυξήσαμε το πλήθος των δεδομένων/κλάσεων από 10 σε 100. Όπως ήταν αναμενόμενο με το cifar100 υπάρχουν πολλές περισσότερες κατηγορίες και επομένως τα μοντέλα μας δυσκολεύονται (περισσότερο από τη χρήση του cifar10) στην κατηγοριοποίηση των εικόνων. Αυτό επίσης να το επαληθεύσουμε συγκρίνοντας τα αποτελέσματα μας με του εργαστηρίου όπου χρησιμοποιήθηκε ένα απλό CNN με cifar10.
# * Οι optimizers που χρησιμοποιήσαμε ήταν οι SGD (μόνο στο LeNet), Adam (σε όλα τα CNN) και Adamax (σε όλα εκτός του LeNet). Όπως ήταν αναμενόμενο καλύτερα αποτελέσματα είχαμε με τους optimizers Adam και Adamax.  Στο CNN LeNet που χρησιμοποιούσαμε μόνο SGD και Adam, ο δεύτερος optimizer είχε το καλύτερο accuracy καθώς και το μικρότερο loss. Στα υπόλοιπα μοντέλα που χρησιμοποίθηκαν  οι Adam και Adamax, ο Adamax υπερτερούσε σε όλες τις περιπτώσεις του Adam, όπως και περιμέναμε αφού αποτελεί επέκταση του.
# * Για την παράμετρο batch size δκομίσαμε τις τιμές 64,128 και 256. Με αυτές τις δοκιμές παρατηρήσαμε ότι είναι δύσκολο να εξάγουμε ένα συμπέρασμα για την ιδανική τιμή του batch size, καθώς διαφέρει ανάλογα με το μοντέλο και το dataset που χρησιμοποιούμε. Ωστόσο, όπως περιμενάμε για μεγαλύτερες τιμές της παραμέτρου, μειώνεται ο χρόνος εκπαίδευσης του κάθε epoch, και συγκλίνει πιο αργά στο training loss (το οποίο παρουσίαζει μεγαλύτερες τιμες).

# %% [markdown]
# Βασιζόμενοι στο εργαστήριο 9.3 του μαθήματος αρχικά δημιουργούμε το συνελικτικό μας και στη συνέχεια το μεταγλωτίζουμε και το εκπαιδεύουμε.
# ## LeNet

# %%
def LeNet():
    return tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(filters=6, kernel_size=5, activation='sigmoid',
                               padding='same'),
        tf.keras.layers.AvgPool2D(pool_size=2, strides=2),
        tf.keras.layers.Conv2D(filters=16, kernel_size=5,
                               activation='sigmoid'),
        tf.keras.layers.AvgPool2D(pool_size=2, strides=2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(120, activation='sigmoid'),
        tf.keras.layers.Dense(100, activation='sigmoid'),
        tf.keras.layers.Dense(100)])

# %%
lenet = LeNet()
lenet.build((None,32,32,3))
lenet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 32, 32, 6)         456
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 16, 16, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 12, 12, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 6, 6, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               69240
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               12100
# ...

# %%
with tf.device('/device:GPU:0'):
  lenet = LeNet()
  lenet.build((None, 32, 32, 3))

  lenet.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.9),  ##lr = 0.9 standard value
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])

  history = lenet.fit(x_train, y_train, epochs=100, batch_size=128,
                      validation_data=(x_test, y_test))

# %%
with tf.device('/device:GPU:0'):
  lenet = LeNet()
  lenet.build((None, 32, 32, 3))

  lenet.compile(optimizer=tf.keras.optimizers.Adam(),  
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])

  history2 = lenet.fit(x_train, y_train, epochs=100, batch_size=128,
                      validation_data=(x_test, y_test))

# %%
with tf.device('/device:GPU:0'):
  lenet = LeNet()
  lenet.build((None, 32, 32, 3))

  lenet.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.9),  ##lr = 0.9 standard value
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])

  history3 = lenet.fit(x_train, y_train, epochs=130, batch_size=64,
                      validation_data=(x_test, y_test))

# %%
with tf.device('/device:GPU:0'):
  lenet = LeNet()
  lenet.build((None, 32, 32, 3))

  lenet.compile(optimizer=tf.keras.optimizers.Adam(),  
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])

  history4 = lenet.fit(x_train, y_train, epochs=130, batch_size=64,
                      validation_data=(x_test, y_test))

# %% [markdown]
# ### Διάγραμμα ορθότητας για optimizer = SGD, loss = crossentropy, epochs = 100, batchsize = 128

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = lenet.evaluate(x_test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 0s - loss: 1.9878 - accuracy: 0.4585
# test_los =  1.9877524375915527
# test_acc =  0.4584999978542328

# %% [markdown]
# ### Διάγραμμα ορθότητας για optimizer = adam, loss = crossentropy,epochs = 100, batchsize = 128

# %%
plt.plot(history2.history['accuracy'], label='accuracy')
plt.plot(history2.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = lenet.evaluate(x_test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 1s - loss: 1.7077 - accuracy: 0.4850
# test_los =  1.7077155113220215
# test_acc =  0.48500001430511475

# %% [markdown]
# ### Διάγραμμα ορθότητας για optimizer = SGD, loss = crossentropy,  epochs = 130, batchsize = 64

# %%
plt.plot(history3.history['accuracy'], label='accuracy')
plt.plot(history3.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = lenet.evaluate(x_test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 1s - loss: 3.4353 - accuracy: 0.4755
# test_los =  3.4353435039520264
# test_acc =  0.4754999876022339

# %% [markdown]
# ### Διάγραμμα ορθότητας για optimizer = adam, loss = crossentropy,epochs = 130, batchsize = 64

# %%
plt.plot(history3.history['accuracy'], label='accuracy')
plt.plot(history3.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = lenet.evaluate(x_test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 1s - loss: 2.2328 - accuracy: 0.4745
# test_los =  2.2328381538391113
# test_acc =  0.47450000047683716

# %% [markdown]
# ## AlexNet

# %%
def AlexNet():
    return tf.keras.models.Sequential([
        # Here, we use a larger 11 x 11 window to capture objects. At the same
        # time, we use a stride of 4 to greatly reduce the height and width of
        # the output. Here, the number of output channels is much larger than
        # that in LeNet
        tf.keras.layers.Conv2D(filters=96, kernel_size=11, strides=4,
                               activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=3, strides=2),
        # Make the convolution window smaller, set padding to 2 for consistent
        # height and width across the input and output, and increase the
        # number of output channels
        tf.keras.layers.Conv2D(filters=256, kernel_size=5, padding='same',
                               activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=3, strides=2),
        # Use three successive convolutional layers and a smaller convolution
        # window. Except for the final convolutional layer, the number of
        # output channels is further increased. Pooling layers are not used to
        # reduce the height and width of input after the first two
        # convolutional layers
        tf.keras.layers.Conv2D(filters=384, kernel_size=3, padding='same',
                               activation='relu'),
        tf.keras.layers.Conv2D(filters=384, kernel_size=3, padding='same',
                               activation='relu'),
        tf.keras.layers.Conv2D(filters=256, kernel_size=3, padding='same',
                               activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=3, strides=2),
        tf.keras.layers.Flatten(),
        # Here, the number of outputs of the fully-connected layer is several
        # times larger than that in LeNet. Use the dropout layer to mitigate
        # overfitting
        tf.keras.layers.Dense(4096, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(4096, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(100)])

# %%
alexnet = AlexNet()
alexnet.build((None, 68,68,3))
alexnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 15, 15, 96)        34944
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 7, 7, 96)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 7, 256)         614656
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 384)         885120
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 384)         1327488
# _________________________________________________________________
# ...

# %% [markdown]
# Στο συγκεκρίμενο σημείο φέρνουμε τα δεδομένα μας στη μορφή που τα θέλει το AlexNet CNN. Αρχικά, κάνουμε normalize τα x_test και x_train και στη συνέχεια τα κάνουμε rescale σε 227x277x3 που απαιτεί το AlexNet

# %%
train = []
test = []

# %%
for i in range(x_train.shape[0]):
  temp = x_train[i]
  temp = tf.image.per_image_standardization(temp)
  temp = tf.image.resize(temp,(227,227))
  train.append(temp)

# %%
for i in range(x_test.shape[0]):
  temp = x_test[i]
  temp = tf.image.per_image_standardization(temp)
  temp = tf.image.resize(temp,(227,227))
  test.append(temp)

# %%
train = np.array(train)
test = np.array(test)

# %%
with tf.device('/device:GPU:0'):
  alexnet = AlexNet()
  alexnet.build((None, 227,227,3))

  alexnet.compile(optimizer=tf.keras.optimizers.Adam(),  
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])

  history6 = alexnet.fit(train, y_train, epochs=100, batch_size=64,
                      validation_data=(test, y_test))

# %%
with tf.device('/device:GPU:0'):  
  alexnet = AlexNet()
  alexnet.build((None, 227,227,3))

  alexnet.compile(optimizer=tf.keras.optimizers.Adamax(),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])
  history7 = alexnet.fit(train, y_train, epochs=60, batch_size=128,
                      validation_data=(test, y_test))

# %% [markdown]
# ### Διάγραμμα ορθότητας για optimizer = adam, loss = crossentropy, epochs = 100, batchsize = 64

# %%
plt.plot(history6.history['accuracy'], label='accuracy')
plt.plot(history6.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = alexnet.evaluate(test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 2s - loss: 2.8706 - accuracy: 0.5165
# test_los =  2.8705849647521973
# test_acc =  0.5164999961853027

# %% [markdown]
# ### Διάγραμμα ορθότητας για optimizer = adamax, loss = crossentropy, epochs = 60, batchsize = 128

# %%
plt.plot(history7.history['accuracy'], label='accuracy')
plt.plot(history7.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = alexnet.evaluate(test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 1s - loss: 3.4377 - accuracy: 0.6150
# test_los =  3.4377171993255615
# test_acc =  0.6150000095367432

# %% [markdown]
# ## VGG

# %%
def vgg_block(num_convs, num_channels):
    blk = tf.keras.models.Sequential()
    for _ in range(num_convs):
        blk.add(
            tf.keras.layers.Conv2D(num_channels, kernel_size=3,
                                   padding='same', activation='relu'))
    blk.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
    return blk

conv_arch = ((1, 64), (1, 128), (2, 256), (2, 512), (2, 512))

def VGG(conv_arch):
    net = tf.keras.models.Sequential()
    # The convulational part
    for (num_convs, num_channels) in conv_arch:
        net.add(vgg_block(num_convs, num_channels))
    # The fully-connected part
    net.add(
        tf.keras.models.Sequential([
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(4096, activation='relu'),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(4096, activation='relu'),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(100)]))
    return net

# %%
vgg = VGG(conv_arch)
vgg.build((None, 32, 32, 3))
vgg.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# sequential_1 (Sequential)    (None, 16, 16, 64)        1792
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 8, 8, 128)         73856
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 4, 4, 256)         885248
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 2, 2, 512)         3539968
# _________________________________________________________________
# sequential_5 (Sequential)    (None, 1, 1, 512)         4719616
# _________________________________________________________________
# sequential_6 (Sequential)    (None, 100)               19292260
# ...
# Total params: 28,512,740
# Trainable params: 28,512,740
# Non-trainable params: 0
# ...

# %%
with tf.device('/device:GPU:0'):  
  vgg2 = VGG(conv_arch)
  vgg2.build((None, 32, 32, 3))

  vgg2.compile(optimizer=tf.keras.optimizers.Adam(),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])

  history = vgg2.fit(x_train, y_train, epochs=100, batch_size=128,
                      validation_data=(x_test, y_test))

# %%
with tf.device('/device:GPU:0'):  
  vgg = VGG(conv_arch)
  vgg.build((None, 32, 32, 3))

  vgg.compile(optimizer=tf.keras.optimizers.Adam(),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])

  history2 = vgg.fit(x_train, y_train, epochs=130, batch_size=64,
                      validation_data=(x_test, y_test))

# %%
conv_arch = ((1, 64), (1, 128), (2, 256), (2, 512), (2, 512))
with tf.device('/device:GPU:0'):  
  vgg4 = VGG(conv_arch)
  vgg4.build((None, 32, 32, 3))

  vgg4.compile(optimizer=tf.keras.optimizers.Adamax(),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])

  history3 = vgg4.fit(x_train, y_train, epochs=80, batch_size=128,
                      validation_data=(x_test, y_test))

# %%
conv_arch = ((1, 64), (1, 128), (2, 256), (2, 512), (2, 512))
with tf.device('/device:GPU:0'):  
  vgg4 = VGG(conv_arch)
  vgg4.build((None, 32, 32, 3))

  vgg4.compile(optimizer=tf.keras.optimizers.Adamax(),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])

  history4 = vgg4.fit(x_train, y_train, epochs=50, batch_size=256,
                      validation_data=(x_test, y_test))

# %% [markdown]
# ### Διάγραμμα ορθότητας για optimizer = adam, loss = crossentropy, epochs = 100, batchsize = 128

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = vgg2.evaluate(x_test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 0s - loss: 2.9992 - accuracy: 0.5570
# test_los =  2.9991753101348877
# test_acc =  0.5569999814033508

# %% [markdown]
# ### Διάγραμμα ορθότητας για optimizer = adam, loss = crossentropy, epochs = 130, batchsize = 64

# %%
plt.plot(history2.history['accuracy'], label='accuracy')
plt.plot(history2.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = vgg.evaluate(x_test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 0s - loss: 3.1453 - accuracy: 0.5075
# test_los =  3.145305871963501
# test_acc =  0.5074999928474426

# %% [markdown]
# ### Διάγραμμα ορθότητας για optimizer = adamax, loss = crossentropy, epochs = 80, batchsize = 128

# %%
plt.plot(history3.history['accuracy'], label='accuracy')
plt.plot(history3.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = vgg4.evaluate(x_test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 1s - loss: 3.3180 - accuracy: 0.5730
# test_los =  3.3179988861083984
# test_acc =  0.5730000138282776

# %% [markdown]
# ### Διάγραμμα ορθότητας για optimizer = adamax, loss = crossentropy, epochs = 50, batchsize = 256

# %%
plt.plot(history4.history['accuracy'], label='accuracy')
plt.plot(history4.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = vgg4.evaluate(x_test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 0s - loss: 3.7660 - accuracy: 0.4905
# test_los =  3.766007900238037
# test_acc =  0.49050000309944153

# %% [markdown]
# ## MyCNN

# %%
def MyCNN():
  MyCNN = models.Sequential()
  MyCNN.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3))) 
  MyCNN.add(layers.MaxPooling2D((2, 2)))
  MyCNN.add(layers.Conv2D(64, (3, 3), activation='relu'))
  MyCNN.add(layers.MaxPooling2D((2, 2)))
  MyCNN.add(layers.Conv2D(128, (3, 3), activation='relu'))
  MyCNN.add(layers.AvgPool2D(pool_size=2, strides=2)) 
  MyCNN.add(layers.Flatten())
  MyCNN.add(layers.Dense(256, activation='relu'))
  MyCNN.add(layers.Dropout(0.5))
  MyCNN.add(layers.Dense(128, activation='relu'))
  MyCNN.add(layers.Dropout(0.5))
  MyCNN.add(layers.Dense(100))
  return MyCNN

mycnn = MyCNN()
mycnn.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_29 (Conv2D)           (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 4, 4, 128)         73856
# _________________________________________________________________
# average_pooling2d_10 (Averag (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 512)               0
# ...

# %%
with tf.device('/device:GPU:0'):  
  mycnn = MyCNN()

  mycnn.compile(optimizer=tf.keras.optimizers.Adam(),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])
  mycnn_history= mycnn.fit(x_train, y_train, epochs=100, batch_size=128,
                      validation_data=(x_test, y_test))

# %%
with tf.device('/device:GPU:0'):  
  mycnn = MyCNN()

  mycnn.compile(optimizer=tf.keras.optimizers.Adamax(),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])
  mycnn_history2= mycnn.fit(x_train, y_train, epochs=100, batch_size=128,
                      validation_data=(x_test, y_test))

# %%
with tf.device('/device:GPU:0'):  
  mycnn = MyCNN()

  mycnn.compile(optimizer=tf.keras.optimizers.Adamax(),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])
  mycnn_history3= mycnn.fit(x_train, y_train, epochs=150, batch_size=128,
                      validation_data=(x_test, y_test))

# %%
with tf.device('/device:GPU:0'):  
  mycnn = MyCNN()

  mycnn.compile(optimizer=tf.keras.optimizers.Adamax(),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])
  mycnn_history4= mycnn.fit(x_train, y_train, epochs=100, batch_size=64,
                      validation_data=(x_test, y_test))

# %% [markdown]
# ### Διάγραμμα ορθότητας για optimizer = adam, loss = crossentropy, epochs = 100, batchsize = 128

# %%
plt.plot(mycnn_history.history['accuracy'], label='accuracy')
plt.plot(mycnn_history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = mycnn.evaluate(x_test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 0s - loss: 2.3163 - accuracy: 0.6380
# test_los =  2.3163492679595947
# test_acc =  0.6380000114440918

# %% [markdown]
# ### Διάγραμμα ορθότητας για optimizer = adamax, loss = crossentropy, epochs = 100, batchsize = 128

# %%
plt.plot(mycnn_history2.history['accuracy'], label='accuracy')
plt.plot(mycnn_history2.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = mycnn.evaluate(x_test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 0s - loss: 1.2463 - accuracy: 0.6195
# test_los =  1.2462785243988037
# test_acc =  0.6194999814033508

# %% [markdown]
# ### Διάγραμμα ορθότητας για optimizer = adamax, loss = crossentropy, epochs = 150, batchsize = 128

# %%
plt.plot(mycnn_history3.history['accuracy'], label='accuracy')
plt.plot(mycnn_history3.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = mycnn.evaluate(x_test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 0s - loss: 1.2979 - accuracy: 0.6415
# test_los =  1.2979307174682617
# test_acc =  0.6414999961853027

# %% [markdown]
# ### Διάγραμμα ορθότητας για optimizer = adamax, loss = crossentropy, epochs = 100, batchsize = 64

# %%
plt.plot(mycnn_history4.history['accuracy'], label='accuracy')
plt.plot(mycnn_history4.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = mycnn.evaluate(x_test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 0s - loss: 1.3247 - accuracy: 0.6600
# test_los =  1.3247326612472534
# test_acc =  0.6600000262260437

# %% [markdown]
# ## Οι καλύτερες ορθότητες από κάθε μοντέλο.

# %% [markdown]
# ### LeNet
# Διάγραμμα ορθότητας για optimizer = adam, loss = crossentropy,epochs = 100, batchsize = 128

# %%
plt.plot(history2.history['accuracy'], label='accuracy')
plt.plot(history2.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = lenet.evaluate(x_test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 1s - loss: 1.7077 - accuracy: 0.4850
# test_los =  1.7077155113220215
# test_acc =  0.48500001430511475

# %% [markdown]
# ### AlexNet
# Διάγραμμα ορθότητας για optimizer = adamax, loss = crossentropy, epochs = 60, batchsize = 128

# %%
plt.plot(history7.history['accuracy'], label='accuracy')
plt.plot(history7.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = alexnet.evaluate(test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 1s - loss: 3.4377 - accuracy: 0.6150
# test_los =  3.4377171993255615
# test_acc =  0.6150000095367432

# %% [markdown]
# ### VGG
# Διάγραμμα ορθότητας για optimizer = adamax, loss = crossentropy, epochs = 80, batchsize = 128

# %%
plt.plot(history3.history['accuracy'], label='accuracy')
plt.plot(history3.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = vgg4.evaluate(x_test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 1s - loss: 3.3180 - accuracy: 0.5730
# test_los =  3.3179988861083984
# test_acc =  0.5730000138282776

# %% [markdown]
# ### MyCNN
# optimizer = adamax, loss = crossentropy, epochs = 100, batchsize = 64

# %%
plt.plot(mycnn_history4.history['accuracy'], label='accuracy')
plt.plot(mycnn_history4.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = mycnn.evaluate(x_test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 0s - loss: 1.3247 - accuracy: 0.6600
# test_los =  1.3247326612472534
# test_acc =  0.6600000262260437

# %% [markdown]
# # Ερώτημα 2

# %% [markdown]
# * Στο δικό μας CNN χρησιμοποιούσαμε ήδη Dropout με στόχο να ελέγξουμε το overfitting όπως ζητάει και το ερώτημα 2.
# * Προσθέτουμε στην αρχή του μοντέλου μας τις 3 παρακάτω εντολές, ώστε να υλοποιήσουμε το Data augmentation που μας ζητάει το ερώτημα:
#   * MyCNN.add(layers.experimental.preprocessing.RandomFlip("horizontal",input_shape=(32, 32, 3)))
#   * MyCNN.add(layers.experimental.preprocessing.RandomRotation(0.1))
#   * MyCNN.add(layers.experimental.preprocessing.RandomZoom(0.1))

# %%
def MyCNN():
  MyCNN = models.Sequential()

  ####################### Data augmentation #########################
  MyCNN.add(layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(32, 32, 3)))
  MyCNN.add(layers.experimental.preprocessing.RandomRotation(0.1))
  MyCNN.add(layers.experimental.preprocessing.RandomZoom(0.1))
  ###################################################################

  MyCNN.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3))) 
  MyCNN.add(layers.MaxPooling2D((2, 2)))
  MyCNN.add(layers.Conv2D(64, (3, 3), activation='relu'))
  MyCNN.add(layers.MaxPooling2D((2, 2)))
  MyCNN.add(layers.Conv2D(128, (3, 3), activation='relu'))
  MyCNN.add(layers.AvgPool2D(pool_size=2, strides=2)) 
  MyCNN.add(layers.Flatten())
  MyCNN.add(layers.Dense(256, activation='relu'))
  ##### Dropout, as previously used #####
  MyCNN.add(layers.Dropout(0.5))
  MyCNN.add(layers.Dense(128, activation='relu'))
  MyCNN.add(layers.Dropout(0.5))
  MyCNN.add(layers.Dense(100))
  return MyCNN

mycnn = MyCNN()
mycnn.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# random_flip_11 (RandomFlip)  (None, 32, 32, 3)         0
# _________________________________________________________________
# random_rotation_11 (RandomRo (None, 32, 32, 3)         0
# _________________________________________________________________
# random_zoom (RandomZoom)     (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 64)          0
# ...

# %%
callback = tf.keras.callbacks.EarlyStopping( 
    monitor="val_loss",
    min_delta=0.001,
    patience=10,
    verbose=0,
    mode="auto", 
    baseline=None,
    restore_best_weights=False,
)
# min_delta: Minimum change in the monitored quantity to qualify as an improvement, i.e. an absolute change of less than min_delta, will count as no improvement.
# patience: Number of epochs with no improvement after which training will be stopped.

# %%
with tf.device('/device:GPU:0'):  
  mycnn = MyCNN()

  mycnn.compile(optimizer=tf.keras.optimizers.Adamax(),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])
  mycnn_history= mycnn.fit(x_train, y_train, epochs=100, batch_size=128,
                      validation_data=(x_test, y_test),callbacks=[callback])

# %%
plt.plot(mycnn_history.history['accuracy'], label='accuracy')
plt.plot(mycnn_history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = mycnn.evaluate(x_test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 0s - loss: 1.3053 - accuracy: 0.6015
# test_los =  1.3053443431854248
# test_acc =  0.6014999747276306

# %%
with tf.device('/device:GPU:0'):  
  mycnn = MyCNN()

  mycnn.compile(optimizer=tf.keras.optimizers.Adamax(),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])
  mycnn_history2 = mycnn.fit(x_train, y_train, epochs=100, batch_size=64,
                      validation_data=(x_test, y_test),callbacks=[callback])

# %%
plt.plot(mycnn_history2.history['accuracy'], label='accuracy')
plt.plot(mycnn_history2.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = mycnn.evaluate(x_test,  y_test, verbose=2)
print("test_los = ",test_loss)
print("test_acc = ",test_acc)
# Out:
# 63/63 - 0s - loss: 1.1793 - accuracy: 0.6520
# test_los =  1.1793261766433716
# test_acc =  0.6520000100135803

# %% [markdown]
# ## Αξιολόγηση ορθότητας
# Σε αρχικές δοκιμές του πρόωρου τερμαρισμού, παρατηρήσαμε ότι για μικρές τιμές του patience και μεγάλες του min_delta, το μοντέλο μας είχε σαφώς χειρότερες επιδόσεις ,όπως και περιμέναμε, αφού σταμάταγε πρόωρα η εκπαίδευση. Έπειτα, επιλέγοντας σωστές τιμές, πήραμε τα παραπάνω διαγράμματα.
# Από τα διαγράμματα παρατηρούμε ότι τα αποτελέσματα είναι παρόμοια με αυτά του αρχικού μοντέλου μας, πριν προσθέσουμε εντολές για τον έλεγχο του overfitting. Η μόνη διαφορά είναι στο δεύτερο διάγραμμα όπου φαίνεται μία μικρή μείωση του loss. Αυτό είναι λογικό αφού ήδη χρησιμοποιούσαμε dropout στο CNN μας το οποίο μείωνε σημαντικά το loss. Η εγκυρότητα σε όλες τις περιπτώσεις παραμένει σχεδόν σταθερή.

# %% [markdown]
# # Ερώτημα 3

# %%
def MyCNN_tf():

  base_model = tf.keras.applications.VGG16(weights='imagenet', input_shape=(32,32,3),include_top=False)

  base_model.trainable = False #freeze convolutiional base
  input = tf.keras.Input(shape=(32, 32, 3))
  data_augmentation = tf.keras.Sequential(
    [
        layers.experimental.preprocessing.RandomFlip("horizontal"),
        layers.experimental.preprocessing.RandomRotation(0.1),
    ]
  )
  x = data_augmentation(input) 
  norm_layer = tf.keras.layers.experimental.preprocessing.Normalization()
  x = norm_layer(x)
  x = base_model(x, training=False)
  x = tf.keras.layers.GlobalAveragePooling2D()(x)
  x = tf.keras.layers.Flatten()(x) 
  x = tf.keras.layers.Dropout(0.2)(x)  
  output = tf.keras.layers.Dense(256, activation='relu')(x)
  x = tf.keras.layers.Dropout(0.2)(x) 
  output = tf.keras.layers.Dense(128, activation='relu')(output)

  model = tf.keras.Model(input, output)  

  return model
  # model = tf.keras.Sequential([
  # tf.keras.layers.InputLayer((32, 32, 3)) ,
  # tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  # tf.keras.layers.experimental.preprocessing.RandomRotation(0.1),     
  # tf.keras.layers.experimental.preprocessing.Normalization(),                    
  # VGG16,
  # tf.keras.layers.MaxPool2D(pool_size=1, strides=1),
  # tf.keras.layers.MaxPool2D(pool_size=1, strides=1),
  # tf.keras.layers.AvgPool2D(pool_size=1, strides=1),
  # tf.keras.layers.Flatten(),
  # tf.keras.layers.Dropout(0.2),
  # tf.keras.layers.Dense(256,activation='relu'),
  # tf.keras.layers.Dropout(0.2),       
  # tf.keras.layers.Dense(128)               
  # ])                               
  # return model

# %%
mycnn = MyCNN_tf()
mycnn.summary()
# Out:
# Model: "model_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_26 (InputLayer)        [(None, 32, 32, 3)]       0
# _________________________________________________________________
# sequential_12 (Sequential)   (None, 32, 32, 3)         0
# _________________________________________________________________
# normalization_12 (Normalizat (None, 32, 32, 3)         7
# _________________________________________________________________
# vgg16 (Functional)           (None, 1, 1, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d_10  (None, 512)               0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 512)               0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 512)               0
# ...

# %%
for i, layer in enumerate(mycnn.layers):
    print(i, layer.name, layer.trainable)
# Out:
# 0 input_26 True
# 1 sequential_12 True
# 2 normalization_12 True
# 3 vgg16 False
# 4 global_average_pooling2d_10 True
# 5 flatten_12 True
# 6 dropout_21 True
# 7 dense_27 True
# 8 dense_28 True

# %%
callback = [
    tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    min_delta=0, 
    patience=10, 
    verbose=0,
    mode='auto', 
    baseline=None, 
    restore_best_weights=False)
]
with tf.device('/device:GPU:0'):  
  mycnn = MyCNN_tf()

  mycnn.compile(optimizer=tf.keras.optimizers.Adamax(),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])
  history = mycnn.fit(x_train, y_train, epochs=100, batch_size=128,
                      validation_data=(x_test, y_test), callbacks= callback)

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = mycnn.evaluate(x_test,  y_test, verbose=2)
# Out:
# 63/63 - 1s - loss: 1.6305 - accuracy: 0.5430

# %%
for output_layer in mycnn.layers[0](mycnn).layers[-3:]:
  output_layer.trainable = True

with tf.device('/device:GPU:0'):  

  mycnn.compile(optimizer=tf.keras.optimizers.Adamax(),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])
  history = mycnn.fit(x_train, y_train, epochs=100, batch_size=128,
                      validation_data=(x_test, y_test), callbacks=callback)

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

test_loss, test_acc = mycnn.evaluate(x_test,  y_test, verbose=2)
# Out:
# 63/63 - 1s - loss: 1.6289 - accuracy: 0.5475

# %% [markdown]
# Εκπαιδεύοντας επιπλέον επίπεδα όπως περιμέναμε η γραφική κυμαίνεται μόνο σε υψηλές τιμές, αφού το μοντέλο μας ήταν ήδη εκαιδευμένο.

# %% [markdown]
# ## Διαχείριση μνήμης (TFRecord)
# Η φόρτωση δεδομένων με τον τρόπο που το κάναμε παραπάνω στο απλό παράδειγμα υλοποίησης είναι πολύ βολική αλλά δεν είναι αποτελεσματική ως προς τη διαχείριση της μνήμης. Συγκεκριμένα, με τον τρόπο αυτό, τα δεδομένα αποθηκεύονται απευθείας σε μεταβλητές, οι οποίες όλες μαζί καταλαμβάνουν τη RAM της CPU ή της GPU, κάτι που κάνει αδύνατη τη διαχείριση μεγάλων datasets ή τον μεταχηματισμό των δεδομένων όπως όταν κάνουμε αύξηση δεδομένων (data augmentation).
#
# Για να παρακαμφθεί αυτό το πρόβλημα, υπάρχει η δυνατότητα της σειριοποίησης των δεδομένων (serialization) και της αποθήκευσής τους σε αρχεία μεσαίου μεγέθους (κάποιων MB) τα οποία μπορούν να αναγνωστούν γραμμικά.
#
# Το φορμάτ TFRecord είναι ένα φορμάτ που επιτρέπει την αποθήκευση σειράς δυαδικών εγγραφών. Διαβάστε σχετικά για το [TFRecord and tf.Example](https://www.tensorflow.org/tutorials/load_data/tfrecord) και [tf.data: Build TensorFlow input pipelines](https://www.tensorflow.org/guide/data).
#
# Σημειώστε ότι με τη μέθοδο αυτή θα πρέπει να γίνει import η `tensorflow_datasets` και να χρησιμοποιήσουμε την `tfds.load` ώστε να αποθηκευθεί το σύνολο δεδομένων σε αρχεία tfrecord στο δίσκο (δείτε [εδώ](https://colab.research.google.com/github/tensorflow/datasets/blob/master/docs/overview.ipynb) ένα παράδειγμα). Φυσικά μπορούμε να μετατρέψουμε και τα πρωτογενή δεδομένα (raw data) του dataset όπως αρχεία jpg σε φορματ tfrecord όπως [εδώ](https://towardsdatascience.com/working-with-tfrecords-and-tf-train-example-36d111b3ff4d).
